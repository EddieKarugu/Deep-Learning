# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2 as cv
import PIL as pil
import tensorflow as tf 
from tensorflow import keras

# %%
dataset_url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz'
tf.keras.utils.get_file('flower_photos', origin=dataset_url, cache_dir='.', untar=True)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 dataset_url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz'
# ----> 2 tf.keras.utils.get_file('flower_photos', origin=dataset_url, cache_dir='.', untar=True)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:339, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     336 if untar:
#     337     archive_format = "tar"
# --> 339 status = extract_archive(
#     340     download_target, extraction_dir, archive_format
#     341 )
#     342 if not status:
#     343     warnings.warn("Could not extract archive.", stacklevel=2)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:117, in extract_archive(file_path, path, archive_format)
#     114         archive.extractall(path)
#     115     else:
#     116         # Tar archive, perhaps unsafe. Filter paths.
# --> 117         archive.extractall(
#     118             path, members=filter_safe_paths(archive)
#     119         )
#     120 except (tarfile.TarError, RuntimeError, KeyboardInterrupt):
#     121     if os.path.exists(path):
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2268, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2263     if tarinfo.isdir():
#    2264         # For directories, delay setting attributes until later,
#    2265         # since permissions can interfere with extraction and
#    2266         # extracting contents can reset mtime.
#    2267         directories.append(tarinfo)
# -> 2268     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2269                       numeric_owner=numeric_owner)
#    2271 # Reverse sort directories.
#    2272 directories.sort(key=lambda a: a.name, reverse=True)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2331, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2328 self._check("r")
#    2330 try:
# -> 2331     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2332                          set_attrs=set_attrs,
#    2333                          numeric_owner=numeric_owner)
#    2334 except OSError as e:
#    2335     self._handle_fatal_error(e)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2414, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2411     self._dbg(1, tarinfo.name)
#    2413 if tarinfo.isreg():
# -> 2414     self.makefile(tarinfo, targetpath)
#    2415 elif tarinfo.isdir():
#    2416     self.makedir(tarinfo, targetpath)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:2467, in TarFile.makefile(self, tarinfo, targetpath)
#    2465     target.truncate()
#    2466 else:
# -> 2467     copyfileobj(source, target, tarinfo.size, ReadError, bufsize)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\tarfile.py:251, in copyfileobj(src, dst, length, exception, bufsize)
#     249 blocks, remainder = divmod(length, bufsize)
#     250 for b in range(blocks):
# --> 251     buf = src.read(bufsize)
#     252     if len(buf) < bufsize:
#     253         raise exception("unexpected end of data")
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\gzip.py:324, in GzipFile.read(self, size)
#     322     import errno
#     323     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 324 return self._buffer.read(size)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File c:\Users\EDWIN\AppData\Local\Programs\Python\Python312\Lib\gzip.py:547, in _GzipReader.read(self, size)
#     545         break
#     546     if buf == b"":
# --> 547         raise EOFError("Compressed file ended before the "
#     548                        "end-of-stream marker was reached")
#     550 self._crc = zlib.crc32(uncompress, self._crc)
#     551 self._stream_size += len(uncompress)
#
# EOFError: Compressed file ended before the end-of-stream marker was reached
